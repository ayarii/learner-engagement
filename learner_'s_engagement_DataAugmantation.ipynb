# %% [markdown]
# <a href="https://colab.research.google.com/github/ayarii/learner-engagement/blob/main/learner_'s_engagement_DataAugmantation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import requests
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sys
import datetime
from tensorflow import keras
from tensorflow.keras.models import Model
import tensorflow as tf
import pathlib
import os
import zipfile
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import roc_curve, auc
from tensorflow.keras import layers
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Activation
from tensorflow.keras import layers, callbacks
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
#Import dataset
data_dir = tf.keras.utils.get_file(
    "dataset.zip",
    "https://github.com/ayarii/learner-engagement/blob/main/Student-engagement-dataset.zip?raw=true",
    extract=False)
with zipfile.ZipFile(data_dir, 'r') as zip_ref:
    zip_ref.extractall('/content/datasets')
data_dir = pathlib.Path('/content/datasets/Student-engagement-dataset')
print(data_dir)
print(os.path.abspath(data_dir))
# Out:
# Downloading data from https://github.com/ayarii/learner-engagement/blob/main/Student-engagement-dataset.zip?raw=true
# 40069772/40069772 [==============================] - 0s 0us/step
# /content/datasets/Student-engagement-dataset
# /content/datasets/Student-engagement-dataset

# %%
# %pylab inline
#learner confused
url_confused = r'https://github.com/ayarii/learner-engagement/blob/main/0020.jpg?raw=true'
resp = requests.get(url_confused, stream=True).raw
image_array_confused = np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_confused.shape}')
image_confused = cv2.imdecode(image_array_confused, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(image_confused, cv2.COLOR_BGR2RGB))
plt.show()

#learner frustrated
url_frustrated = r'https://github.com/ayarii/learner-engagement/blob/main/135.jpg?raw=true'
resp = requests.get(url_frustrated, stream=True).raw
image_array_frustrated= np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_frustrated.shape}')
image_frustrated = cv2.imdecode(image_array_frustrated, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(image_frustrated, cv2.COLOR_BGR2RGB))
plt.show()

#learner engaged
url_engaged = r'https://github.com/ayarii/learner-engagement/blob/main/0076.jpg?raw=true'
resp = requests.get(url_engaged, stream=True).raw
image_array_engagement = np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_engagement.shape}')
image_engagement = cv2.imdecode(image_array_engagement, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(image_engagement, cv2.COLOR_BGR2RGB))
plt.show()

#learner bored
url_bored = r'https://github.com/ayarii/learner-engagement/blob/main/0153.jpg?raw=true'
resp = requests.get(url_bored, stream=True).raw
image_array_bored = np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_bored.shape}')
image_bored = cv2.imdecode(image_array_bored, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(image_bored, cv2.COLOR_BGR2RGB))
plt.show()

#learner drowsy
url_drowsy = r'https://github.com/ayarii/learner-engagement/blob/main/0021.jpg?raw=true'
resp = requests.get(url_drowsy, stream=True).raw
image_array_drowsy = np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_drowsy.shape}')
image_drowsy = cv2.imdecode(image_array_drowsy, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(image_drowsy, cv2.COLOR_BGR2RGB))
plt.show()

# learner looking_away
url_looking_away = r'https://github.com/ayarii/learner-engagement/blob/main/0011.jpg?raw=true'
resp = requests.get(url_looking_away, stream=True).raw
image_array_looking_away = np.asarray(bytearray(resp.read()), dtype="uint8")
print(f'Shape of the image {image_array_looking_away.shape}')
image_looking_away = cv2.imdecode(image_array_looking_away, cv2.IMREAD_COLOR)
plt.axis('off')
plt.imshow(cv2.cvtColor(image_looking_away, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Shape of the image (72307,)
# Shape of the image (19745,)
# Shape of the image (21216,)
# Shape of the image (21813,)
# Shape of the image (17353,)
# Shape of the image (44759,)

# %%
#Train CNN using data-augmentation
# Create an instance of the ImageDataGenerator for data augmentation
batch_size = 64
img_height = 200
img_width = 200
# Create an ImageDataGenerator for data augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Split data into training and validation
)

# Generate training dataset
train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    #class_mode='categorical',  # Assuming you have categorical labels
    subset='training'  # Specify the subset as training
)

# Generate validation dataset
val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    #class_mode='categorical',
    subset='validation'  # Specify the subset as validation
)

# Verify the class indices
print(train_generator.class_indices)
print(train_generator)
# Out:
# Found 1699 images belonging to 6 classes.
# Found 421 images belonging to 6 classes.
# {'Looking Away': 0, 'bored': 1, 'confused': 2, 'drowsy': 3, 'engaged': 4, 'frustrated': 5}
# <keras.src.preprocessing.image.DirectoryIterator object at 0x7a67d2d2cb80>

# %%
#The number of samples in your dataset after applying data augmentation.
num_original_samples = len(train_generator.filenames)  # Number of original samples in your dataset
batch_size = train_generator.batch_size  # Batch size used during training
num_augmented_samples_per_epoch = num_original_samples * batch_size
num_epochs = 100  # Replace with the actual number of epochs
total_augmented_samples = num_epochs * num_augmented_samples_per_epoch

# Number of Samples:
num_samples = len(train_generator)
print("Number of augmented samples:", num_samples)

#Class Distribution:
class_distribution = train_generator.classes
unique_classes = set(class_distribution)

for class_label in unique_classes:
    count = sum(1 for label in class_distribution if label == class_label)
    print(f"Class {class_label}: {count} samples")

# Print the results
print("Number of original samples:", num_original_samples)
print("Batch size during training:", batch_size)
print("Number of augmented samples per epoch:", num_augmented_samples_per_epoch)
print("Number of epochs:", num_epochs)
print("Total number of augmented samples:", total_augmented_samples)


#Visual Inspection:
import matplotlib.pyplot as plt

# Display a few augmented images
images, labels = train_generator.next()

plt.figure(figsize=(10, 10))
for i in range(min(9, batch_size)):
    plt.subplot(3, 3, i + 1)
    plt.imshow(images[i])
    plt.title(f"Class: {labels[i]}")
    plt.axis("off")

plt.show()
# Out:
# Number of augmented samples: 27
# Class 0: 339 samples
# Class 1: 287 samples
# Class 2: 296 samples
# Class 3: 211 samples
# Class 4: 278 samples
# Class 5: 288 samples
# Number of original samples: 1699
# Batch size during training: 64
# Number of augmented samples per epoch: 108736
# Number of epochs: 100
# Total number of augmented samples: 10873600
# <ipython-input-6-7f71695e6234>:17: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.fromiter(generator)) or the python sum builtin instead.
#   count = sum(1 for label in class_distribution if label == class_label)

# %%
#create the model
num_classes = 6
img_size = (200, 200,3)
model = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(200, 200, 3)),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 200, 200, 3)       0
#
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 99, 99, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 32)        9248
#
#  max_pooling2d_1 (MaxPoolin  (None, 48, 48, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 32)        9248
#
#  max_pooling2d_2 (MaxPoolin  (None, 23, 23, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 16928)             0
#
#  dense (Dense)               (None, 128)               2166912
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 2187078 (8.34 MB)
# Trainable params: 2187078 (8.34 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Set up callbacks
log_dir = "logs/"
tensorboard_callback = callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_images=True)
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Compile your model

model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

# %%
# Train your model using the augmented dataset
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=100,
    #callbacks=[tensorboard_callback, early_stopping]
    )
# Out:
# Epoch 1/100
# 27/27 [==============================] - 34s 1s/step - loss: 1.7868 - accuracy: 0.2178 - val_loss: 1.7766 - val_accuracy: 0.1995
# Epoch 2/100
# 27/27 [==============================] - 27s 978ms/step - loss: 1.6688 - accuracy: 0.3302 - val_loss: 1.4133 - val_accuracy: 0.6603
# Epoch 3/100
# 27/27 [==============================] - 28s 1s/step - loss: 0.9948 - accuracy: 0.6845 - val_loss: 1.0450 - val_accuracy: 0.5796
# Epoch 4/100
# 27/27 [==============================] - 26s 963ms/step - loss: 0.5625 - accuracy: 0.8146 - val_loss: 0.7558 - val_accuracy: 0.7387
# Epoch 5/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.3638 - accuracy: 0.8634 - val_loss: 0.6250 - val_accuracy: 0.6888
# Epoch 6/100
# 27/27 [==============================] - 27s 995ms/step - loss: 0.2744 - accuracy: 0.8994 - val_loss: 0.7381 - val_accuracy: 0.7791
# Epoch 7/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.2344 - accuracy: 0.9211 - val_loss: 0.6647 - val_accuracy: 0.7601
# Epoch 8/100
# 27/27 [==============================] - 27s 996ms/step - loss: 0.1936 - accuracy: 0.9347 - val_loss: 0.8256 - val_accuracy: 0.7838
# Epoch 9/100
# 27/27 [==============================] - 27s 998ms/step - loss: 0.1912 - accuracy: 0.9335 - val_loss: 0.8381 - val_accuracy: 0.7601
# Epoch 10/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.1871 - accuracy: 0.9311 - val_loss: 0.6987 - val_accuracy: 0.7862
# Epoch 11/100
# 27/27 [==============================] - 27s 992ms/step - loss: 0.1400 - accuracy: 0.9447 - val_loss: 0.7972 - val_accuracy: 0.8029
# Epoch 12/100
# 27/27 [==============================] - 27s 992ms/step - loss: 0.1489 - accuracy: 0.9453 - val_loss: 0.7215 - val_accuracy: 0.7910
# Epoch 13/100
# 27/27 [==============================] - 27s 978ms/step - loss: 0.1304 - accuracy: 0.9482 - val_loss: 0.7274 - val_accuracy: 0.7767
# Epoch 14/100
# 27/27 [==============================] - 26s 984ms/step - loss: 0.1387 - accuracy: 0.9411 - val_loss: 0.9210 - val_accuracy: 0.8171
# Epoch 15/100
# 27/27 [==============================] - 31s 1s/step - loss: 0.1437 - accuracy: 0.9429 - val_loss: 0.8037 - val_accuracy: 0.8171
# Epoch 16/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.1208 - accuracy: 0.9453 - val_loss: 0.7353 - val_accuracy: 0.7981
# Epoch 17/100
# 27/27 [==============================] - 27s 996ms/step - loss: 0.1208 - accuracy: 0.9500 - val_loss: 0.7602 - val_accuracy: 0.8124
# Epoch 18/100
# 27/27 [==============================] - 26s 986ms/step - loss: 0.1313 - accuracy: 0.9406 - val_loss: 0.7528 - val_accuracy: 0.8337
# Epoch 19/100
# 27/27 [==============================] - 27s 997ms/step - loss: 0.1186 - accuracy: 0.9517 - val_loss: 0.6848 - val_accuracy: 0.8409
# Epoch 20/100
# 27/27 [==============================] - 26s 989ms/step - loss: 0.1148 - accuracy: 0.9488 - val_loss: 0.6566 - val_accuracy: 0.8432
# Epoch 21/100
# 27/27 [==============================] - 27s 994ms/step - loss: 0.0985 - accuracy: 0.9594 - val_loss: 0.7956 - val_accuracy: 0.8337
# Epoch 22/100
# 27/27 [==============================] - 27s 992ms/step - loss: 0.0974 - accuracy: 0.9541 - val_loss: 0.7062 - val_accuracy: 0.8100
# Epoch 23/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.1233 - accuracy: 0.9447 - val_loss: 0.6275 - val_accuracy: 0.8147
# Epoch 24/100
# 27/27 [==============================] - 26s 989ms/step - loss: 0.1074 - accuracy: 0.9500 - val_loss: 0.6942 - val_accuracy: 0.8266
# Epoch 25/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.1010 - accuracy: 0.9511 - val_loss: 0.5847 - val_accuracy: 0.8456
# Epoch 26/100
# 27/27 [==============================] - 27s 991ms/step - loss: 0.0853 - accuracy: 0.9635 - val_loss: 0.7067 - val_accuracy: 0.7957
# Epoch 27/100
# 27/27 [==============================] - 26s 986ms/step - loss: 0.0942 - accuracy: 0.9553 - val_loss: 0.6888 - val_accuracy: 0.8432
# Epoch 28/100
# 27/27 [==============================] - 26s 989ms/step - loss: 0.0995 - accuracy: 0.9529 - val_loss: 0.7475 - val_accuracy: 0.8361
# Epoch 29/100
# 27/27 [==============================] - 27s 993ms/step - loss: 0.0887 - accuracy: 0.9564 - val_loss: 0.6943 - val_accuracy: 0.8480
# Epoch 30/100
# 27/27 [==============================] - 26s 984ms/step - loss: 0.0829 - accuracy: 0.9553 - val_loss: 0.7602 - val_accuracy: 0.8480
# Epoch 31/100
# 27/27 [==============================] - 27s 994ms/step - loss: 0.1052 - accuracy: 0.9500 - val_loss: 0.7972 - val_accuracy: 0.8337
# Epoch 32/100
# 27/27 [==============================] - 27s 991ms/step - loss: 0.0807 - accuracy: 0.9623 - val_loss: 0.6270 - val_accuracy: 0.8361
# Epoch 33/100
# 27/27 [==============================] - 27s 994ms/step - loss: 0.0854 - accuracy: 0.9570 - val_loss: 0.6379 - val_accuracy: 0.8575
# Epoch 34/100
# 27/27 [==============================] - 27s 992ms/step - loss: 0.0781 - accuracy: 0.9588 - val_loss: 0.6767 - val_accuracy: 0.8480
# Epoch 35/100
# 27/27 [==============================] - 27s 997ms/step - loss: 0.0867 - accuracy: 0.9612 - val_loss: 0.7263 - val_accuracy: 0.8219
# Epoch 36/100
# 27/27 [==============================] - 26s 959ms/step - loss: 0.0828 - accuracy: 0.9582 - val_loss: 0.7294 - val_accuracy: 0.8314
# Epoch 37/100
# 27/27 [==============================] - 27s 997ms/step - loss: 0.0788 - accuracy: 0.9600 - val_loss: 0.6896 - val_accuracy: 0.8147
# Epoch 38/100
# 27/27 [==============================] - 26s 990ms/step - loss: 0.0847 - accuracy: 0.9570 - val_loss: 0.7596 - val_accuracy: 0.8337
# Epoch 39/100
# 27/27 [==============================] - 27s 997ms/step - loss: 0.0879 - accuracy: 0.9600 - val_loss: 0.8182 - val_accuracy: 0.8504
# Epoch 40/100
# 27/27 [==============================] - 27s 1000ms/step - loss: 0.0811 - accuracy: 0.9588 - val_loss: 0.7538 - val_accuracy: 0.8337
# Epoch 41/100
# 27/27 [==============================] - 26s 983ms/step - loss: 0.0783 - accuracy: 0.9582 - val_loss: 0.7229 - val_accuracy: 0.8432
# Epoch 42/100
# 27/27 [==============================] - 27s 989ms/step - loss: 0.0805 - accuracy: 0.9612 - val_loss: 0.8220 - val_accuracy: 0.8432
# Epoch 43/100
# 27/27 [==============================] - 26s 980ms/step - loss: 0.0742 - accuracy: 0.9617 - val_loss: 0.7338 - val_accuracy: 0.8527
# Epoch 44/100
# 27/27 [==============================] - 27s 993ms/step - loss: 0.0858 - accuracy: 0.9612 - val_loss: 0.7469 - val_accuracy: 0.8195
# Epoch 45/100
# 27/27 [==============================] - 26s 970ms/step - loss: 0.0776 - accuracy: 0.9629 - val_loss: 0.7228 - val_accuracy: 0.8385
# Epoch 46/100
# 27/27 [==============================] - 27s 992ms/step - loss: 0.0716 - accuracy: 0.9641 - val_loss: 0.6598 - val_accuracy: 0.8385
# Epoch 47/100
# 27/27 [==============================] - 26s 968ms/step - loss: 0.0727 - accuracy: 0.9623 - val_loss: 0.7675 - val_accuracy: 0.8124
# Epoch 48/100
# 27/27 [==============================] - 26s 979ms/step - loss: 0.0874 - accuracy: 0.9617 - val_loss: 0.7816 - val_accuracy: 0.8290
# Epoch 49/100
# 27/27 [==============================] - 26s 969ms/step - loss: 0.0770 - accuracy: 0.9635 - val_loss: 0.7114 - val_accuracy: 0.8361
# Epoch 50/100
# 27/27 [==============================] - 26s 982ms/step - loss: 0.0771 - accuracy: 0.9606 - val_loss: 0.7487 - val_accuracy: 0.8409
# Epoch 51/100
# 27/27 [==============================] - 25s 948ms/step - loss: 0.0725 - accuracy: 0.9659 - val_loss: 0.7420 - val_accuracy: 0.8456
# Epoch 52/100
# 27/27 [==============================] - 26s 989ms/step - loss: 0.0703 - accuracy: 0.9682 - val_loss: 0.8055 - val_accuracy: 0.8147
# Epoch 53/100
# 27/27 [==============================] - 26s 971ms/step - loss: 0.0695 - accuracy: 0.9641 - val_loss: 0.7361 - val_accuracy: 0.8551
# Epoch 54/100
# 27/27 [==============================] - 27s 1s/step - loss: 0.0691 - accuracy: 0.9623 - val_loss: 0.7386 - val_accuracy: 0.8409
# Epoch 55/100
# 27/27 [==============================] - 26s 979ms/step - loss: 0.0722 - accuracy: 0.9641 - val_loss: 0.7776 - val_accuracy: 0.8551
# Epoch 56/100
# 27/27 [==============================] - 26s 975ms/step - loss: 0.0695 - accuracy: 0.9647 - val_loss: 0.7046 - val_accuracy: 0.8456
# Epoch 57/100
# 27/27 [==============================] - 26s 972ms/step - loss: 0.0773 - accuracy: 0.9635 - val_loss: 0.9750 - val_accuracy: 0.8337
# Epoch 58/100
# 27/27 [==============================] - 26s 984ms/step - loss: 0.0846 - accuracy: 0.9600 - val_loss: 0.7883 - val_accuracy: 0.8290
# Epoch 59/100
# 27/27 [==============================] - 26s 984ms/step - loss: 0.0731 - accuracy: 0.9641 - val_loss: 0.7974 - val_accuracy: 0.8219
# Epoch 60/100
# 27/27 [==============================] - 26s 965ms/step - loss: 0.0706 - accuracy: 0.9612 - val_loss: 0.8115 - val_accuracy: 0.8195
# Epoch 61/100
# 27/27 [==============================] - 26s 985ms/step - loss: 0.0780 - accuracy: 0.9665 - val_loss: 0.7774 - val_accuracy: 0.8266
# Epoch 62/100
# 27/27 [==============================] - 27s 993ms/step - loss: 0.0948 - accuracy: 0.9500 - val_loss: 0.7301 - val_accuracy: 0.8409
# Epoch 63/100
# 27/27 [==============================] - 26s 967ms/step - loss: 0.1252 - accuracy: 0.9459 - val_loss: 0.9141 - val_accuracy: 0.8124
# Epoch 64/100
# 27/27 [==============================] - 25s 933ms/step - loss: 0.0923 - accuracy: 0.9511 - val_loss: 1.0357 - val_accuracy: 0.8242
# Epoch 65/100
# 27/27 [==============================] - 25s 920ms/step - loss: 0.0785 - accuracy: 0.9629 - val_loss: 0.8210 - val_accuracy: 0.8337
# Epoch 66/100
# 27/27 [==============================] - 26s 958ms/step - loss: 0.0791 - accuracy: 0.9576 - val_loss: 0.7134 - val_accuracy: 0.8314
# Epoch 67/100
# 27/27 [==============================] - 30s 1s/step - loss: 0.0759 - accuracy: 0.9647 - val_loss: 0.8095 - val_accuracy: 0.8432
# Epoch 68/100
# 27/27 [==============================] - 26s 974ms/step - loss: 0.0741 - accuracy: 0.9635 - val_loss: 0.7557 - val_accuracy: 0.8219
# Epoch 69/100
# 27/27 [==============================] - 26s 969ms/step - loss: 0.0718 - accuracy: 0.9670 - val_loss: 0.7539 - val_accuracy: 0.8219
# Epoch 70/100
# 27/27 [==============================] - 26s 980ms/step - loss: 0.0721 - accuracy: 0.9659 - val_loss: 0.8809 - val_accuracy: 0.8195
# Epoch 71/100
# 27/27 [==============================] - 26s 984ms/step - loss: 0.0684 - accuracy: 0.9676 - val_loss: 0.7496 - val_accuracy: 0.8290
# Epoch 72/100
# 27/27 [==============================] - 26s 983ms/step - loss: 0.0678 - accuracy: 0.9629 - val_loss: 0.7996 - val_accuracy: 0.8361
# Epoch 73/100
# 27/27 [==============================] - 26s 970ms/step - loss: 0.0706 - accuracy: 0.9594 - val_loss: 0.8254 - val_accuracy: 0.8337
# Epoch 74/100
# 27/27 [==============================] - 27s 993ms/step - loss: 0.0723 - accuracy: 0.9670 - val_loss: 0.7611 - val_accuracy: 0.8456
# Epoch 75/100
# 27/27 [==============================] - 26s 985ms/step - loss: 0.0694 - accuracy: 0.9665 - val_loss: 0.7072 - val_accuracy: 0.8242
# Epoch 76/100
# 27/27 [==============================] - 26s 990ms/step - loss: 0.0673 - accuracy: 0.9641 - val_loss: 0.8126 - val_accuracy: 0.8504
# Epoch 77/100
# 27/27 [==============================] - 26s 951ms/step - loss: 0.0680 - accuracy: 0.9659 - val_loss: 0.8038 - val_accuracy: 0.8432
# Epoch 78/100
# 27/27 [==============================] - 26s 987ms/step - loss: 0.0725 - accuracy: 0.9653 - val_loss: 0.7589 - val_accuracy: 0.8219
# Epoch 79/100
# 27/27 [==============================] - 30s 1s/step - loss: 0.0622 - accuracy: 0.9688 - val_loss: 0.8991 - val_accuracy: 0.8504
# Epoch 80/100
# 27/27 [==============================] - 26s 990ms/step - loss: 0.0678 - accuracy: 0.9623 - val_loss: 0.7892 - val_accuracy: 0.8456
# Epoch 81/100
# 27/27 [==============================] - 30s 1s/step - loss: 0.0651 - accuracy: 0.9641 - val_loss: 0.7946 - val_accuracy: 0.8432
# Epoch 82/100
# 27/27 [==============================] - 26s 977ms/step - loss: 0.0656 - accuracy: 0.9635 - val_loss: 0.8985 - val_accuracy: 0.8409
# Epoch 83/100
# 27/27 [==============================] - 26s 974ms/step - loss: 0.0732 - accuracy: 0.9670 - val_loss: 0.8036 - val_accuracy: 0.8147
# Epoch 84/100
# 27/27 [==============================] - 26s 979ms/step - loss: 0.0742 - accuracy: 0.9653 - val_loss: 0.8525 - val_accuracy: 0.8432
# Epoch 85/100
# 27/27 [==============================] - 26s 981ms/step - loss: 0.0620 - accuracy: 0.9670 - val_loss: 0.8103 - val_accuracy: 0.8361
# Epoch 86/100
# 27/27 [==============================] - 26s 970ms/step - loss: 0.0648 - accuracy: 0.9659 - val_loss: 0.8289 - val_accuracy: 0.8456
# Epoch 87/100
# 27/27 [==============================] - 26s 981ms/step - loss: 0.0661 - accuracy: 0.9670 - val_loss: 0.8387 - val_accuracy: 0.8314
# Epoch 88/100
# 27/27 [==============================] - 26s 973ms/step - loss: 0.0658 - accuracy: 0.9665 - val_loss: 0.7498 - val_accuracy: 0.8409
# Epoch 89/100
# 27/27 [==============================] - 26s 978ms/step - loss: 0.0708 - accuracy: 0.9617 - val_loss: 0.8634 - val_accuracy: 0.8147
# Epoch 90/100
# 27/27 [==============================] - 26s 969ms/step - loss: 0.0616 - accuracy: 0.9670 - val_loss: 0.8400 - val_accuracy: 0.8266
# Epoch 91/100
# 27/27 [==============================] - 26s 978ms/step - loss: 0.0630 - accuracy: 0.9688 - val_loss: 0.8151 - val_accuracy: 0.8242
# Epoch 92/100
# 27/27 [==============================] - 26s 990ms/step - loss: 0.0608 - accuracy: 0.9712 - val_loss: 0.8409 - val_accuracy: 0.8290
# Epoch 93/100
# 27/27 [==============================] - 26s 958ms/step - loss: 0.0726 - accuracy: 0.9670 - val_loss: 0.8847 - val_accuracy: 0.8076
# Epoch 94/100
# 27/27 [==============================] - 26s 965ms/step - loss: 0.0714 - accuracy: 0.9612 - val_loss: 0.9205 - val_accuracy: 0.8337
# Epoch 95/100
# 27/27 [==============================] - 26s 978ms/step - loss: 0.0765 - accuracy: 0.9647 - val_loss: 0.7754 - val_accuracy: 0.8219
# Epoch 96/100
# 27/27 [==============================] - 26s 944ms/step - loss: 0.0586 - accuracy: 0.9694 - val_loss: 0.8559 - val_accuracy: 0.8314
# Epoch 97/100
# 27/27 [==============================] - 26s 969ms/step - loss: 0.0661 - accuracy: 0.9659 - val_loss: 0.8229 - val_accuracy: 0.8171
# Epoch 98/100
# 27/27 [==============================] - 26s 967ms/step - loss: 0.0646 - accuracy: 0.9659 - val_loss: 0.9744 - val_accuracy: 0.8409
# Epoch 99/100
# 27/27 [==============================] - 26s 963ms/step - loss: 0.0658 - accuracy: 0.9688 - val_loss: 0.8586 - val_accuracy: 0.8076
# Epoch 100/100
# 27/27 [==============================] - 26s 967ms/step - loss: 0.0636 - accuracy: 0.9676 - val_loss: 0.9750 - val_accuracy: 0.8219

# %%
# Evaluate the model
loss, accuracy = model.evaluate(val_generator, verbose=0)
print(f'vall loss: {loss:.4f}')
print(f'vall accuracy: {accuracy:.4f}')
# Out:
# vall loss: 0.8388
# vall accuracy: 0.8171

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history['val_accuracy'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy"])
plt.show()

# %%
plt.plot(history.history["loss"])
plt.plot(history.history['val_loss'])
plt.title("model loss")
plt.ylabel("loss")
plt.xlabel("Epoch")
plt.legend(["loss","Validation loss"])
plt.show()

# %%
# Plot the training and validation loss
plt.plot(history.history["accuracy"])
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])
plt.show()
